# %% [markdown]
# # load packages

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # import files

# %%
G1E_overlap_counts= open('/Users/cmdb/qbb2020-answers/week_5_homework/G1E_intron_extron_promoter_list.txt', 'r')
ER4_overlap_counts= open('/Users/cmdb/qbb2020-answers/week_5_homework/ER4_intron_extron_promoter_list.txt', 'r')
peaks= open('/Users/cmdb/qbb2020-answers/week_5_homework/gained_lost.txt')

for i in peaks: 
    print(i)
# Out:
#      810 peaks_gained.bed
#
#      362 peaks_lost.bed
#
#     1172 total

# %% [markdown]
# # create plots with subplot

# %%
plt.rcParams.update({'font.size': 30})

fig, ax = plt.subplots(1,2, figsize=(60,30))


labels = ['Intron', 'Exon', 'Promoter']
G1E = [301, 117, 51]
ER4 = [349, 144, 72]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

ax[0].bar(x - width/2, G1E, width, label='G1E')
ax[0].bar(x + width/2, ER4, width, label='ER4')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax[0].set_ylabel('Counts')
ax[0].set_title('CTCF binding sites in each type of region')
ax[0].set_xticks(x)
ax[0].set_xticklabels(labels)
ax[0].legend()

labels2 = ['Peaks Gained', 'Peaks Lost']
peaks_gained=[810]
peaks_lost=[362]

x2=np.arange(len(labels2))  # the label locations
width = 0.5  # the width of the bars


ax[1].bar(labels2[0], peaks_gained, width, label='gained')
ax[1].bar(labels2[1], peaks_lost, width, label='lost')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax[1].set_ylabel('Counts')
ax[1].set_title('Peaks gained and peaks lost during G1E differentiation')
ax[1].set_xticks(x2)
ax[1].set_xticklabels(labels2)
ax[1].legend()
fig.tight_layout()

plt.show()
